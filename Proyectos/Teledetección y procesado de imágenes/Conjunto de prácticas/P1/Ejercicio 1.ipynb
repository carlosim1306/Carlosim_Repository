# %%
import numpy

# %%
x = numpy.arange(0, numpy.pi, 0.01)
y = numpy.sin(x)
z = numpy.cos(x)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure(1)
plt.plot(x)
plt.ylabel('Lista de valores x')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">

# %%
plt.figure(2)
plt.plot(y)
plt.ylabel('Lista de valores y')
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# Text(0, 0.5, 'Lista de valores y')

# %%
plt.figure(3)
plt.plot(x,y)
plt.ylabel('Sin(x)')
plt.ylabel('x')
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# Text(0, 0.5, 'x')

# %%
plt.figure(4)
plt.plot(x,y,'r')
plt.plot(x,z,'g')
plt.legend(['Sin(x)', 'Cos(x)'])
plt.xlabel('x')
plt.ylabel('Values')
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
# Text(0, 0.5, 'Values')
